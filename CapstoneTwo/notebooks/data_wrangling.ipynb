# %%
#Capstone Two: Data Wrangling
#Created on August 29, 2022

# %%
#Import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#View all columns in DataFrame
pd.options.display.max_columns=10000

# %%
#Import and view train data set using read_csv
train = pd.read_csv('../data/raw/train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Import test data set
test = pd.read_csv('../data/raw/test.csv')
test #All columns except sale price (target variable)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
#Print shape of train and test data
print(train.shape, test.shape)
# Out:
# (1460, 81) (1459, 80)

# %%
#Find any duplicated entries
ids = train['Id']
train[ids.isin(ids.duplicated())].sort_values("Id")
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
#Observe data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Find null values
train.isna().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
#concatenate data frames horizontally (pd.concat[df, df2], axis=1) 
#[train, train.isna()] = double number of columns. 

#only 2 lines for missing continuous values.

# %%
#Explore missing values and figure out what to replace NaN's with.
missing_train = train[['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
                      'GarageYrBlt', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual',
                      'BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 
                      'MasVnrArea', 'MasVnrType', 'Electrical']]
missing_train.head(30)
# Out:
#    PoolQC MiscFeature Alley  Fence FireplaceQu  GarageYrBlt GarageCond  \
# 0     NaN         NaN   NaN    NaN         NaN       2003.0         TA
# 1     NaN         NaN   NaN    NaN          TA       1976.0         TA
# 2     NaN         NaN   NaN    NaN          TA       2001.0         TA
# 3     NaN         NaN   NaN    NaN          Gd       1998.0         TA
# 4     NaN         NaN   NaN    NaN          TA       2000.0         TA
# 5     NaN        Shed   NaN  MnPrv         NaN       1993.0         TA
# 6     NaN         NaN   NaN    NaN          Gd       2004.0         TA
# 7     NaN        Shed   NaN    NaN          TA       1973.0         TA
# 8     NaN         NaN   NaN    NaN          TA       1931.0         TA
# 9     NaN         NaN   NaN    NaN          TA       1939.0         TA
# 10    NaN         NaN   NaN    NaN         NaN       1965.0         TA
# 11    NaN         NaN   NaN    NaN          Gd       2005.0         TA
# ...

# %%
#Explore garage further
missing_train[missing_train['GarageYrBlt'].isnull()]
#Those observations with missing garage data have missing values across all Garage columns
#Do these houses not have garages?
#Checked data_description.txt and NA = No Garage
# Out:
#      PoolQC MiscFeature Alley  Fence FireplaceQu  GarageYrBlt GarageCond  \
# 39      NaN         NaN   NaN    NaN         NaN          NaN        NaN
# 48      NaN         NaN   NaN    NaN         NaN          NaN        NaN
# 78      NaN         NaN   NaN    NaN         NaN          NaN        NaN
# 88      NaN         NaN   NaN  MnPrv         NaN          NaN        NaN
# 89      NaN         NaN   NaN    NaN         NaN          NaN        NaN
# ...     ...         ...   ...    ...         ...          ...        ...
# 1349    NaN         NaN  Pave    NaN         NaN          NaN        NaN
# 1407    NaN         NaN   NaN  MnPrv         NaN          NaN        NaN
# 1449    NaN         NaN   NaN    NaN         NaN          NaN        NaN
# 1450    NaN         NaN   NaN    NaN         NaN          NaN        NaN
# 1453    NaN         NaN   NaN    NaN         NaN          NaN        NaN
#
#      GarageType GarageFinish GarageQual BsmtFinType2 BsmtExposure BsmtQual  \
# ...

# %%
missing_train.isna()
# Out:
#       PoolQC  MiscFeature  Alley  Fence  FireplaceQu  GarageYrBlt  GarageCond  \
# 0       True         True   True   True         True        False       False
# 1       True         True   True   True        False        False       False
# 2       True         True   True   True        False        False       False
# 3       True         True   True   True        False        False       False
# 4       True         True   True   True        False        False       False
# ...      ...          ...    ...    ...          ...          ...         ...
# 1455    True         True   True   True        False        False       False
# 1456    True         True   True  False        False        False       False
# 1457    True        False   True  False        False        False       False
# 1458    True         True   True   True         True        False       False
# 1459    True         True   True   True         True        False       False
#
# ...

# %%
#Explore Masonry veneer type missing values
#Descriptions say "None" = house does not have that feature but there are also NaNs
#Create new df of MasvnrArea and MasVnrType
masvnr = missing_train[['MasVnrType']]
masvnr.head()
# Out:
#   MasVnrType
# 0    BrkFace
# 1       None
# 2    BrkFace
# 3       None
# 4    BrkFace

# %%
#Find missing indeces and turn it into list
missing_train[missing_train['MasVnrArea'].isnull()].index.tolist()
# Out:
# [234, 529, 650, 936, 973, 977, 1243, 1278]

# %%
#Assign the list to variable 'L' and print all missing data of masvnr
L = [234, 529, 650, 936, 973, 977, 1243, 1278]
masvnr = masvnr.loc[L]
masvnr #NaN values are in both columns so I'll assume houses do not have these features
#Replace NaNs with 'None'
# Out:
#      MasVnrType
# 234         NaN
# 529         NaN
# 650         NaN
# 936         NaN
# 973         NaN
# 977         NaN
# 1243        NaN
# 1278        NaN

# %%
#View data for house with missing Electrical data
#Assume the house has electricity and NaN is an error
#Fill missing value with most common occurance
train[train['Electrical'].isnull()].T
# Out:
#                  1379
# Id               1380
# MSSubClass         80
# MSZoning           RL
# LotFrontage      73.0
# LotArea          9735
# ...               ...
# MoSold              5
# YrSold           2008
# SaleType           WD
# SaleCondition  Normal
# SalePrice      167500
#
# [81 rows x 1 columns]

# %%
#View LotFrontage column.
train['LotFrontage'].head(20)
#Continuous variable
#Fill na with 0
# Out:
# 0     65.0
# 1     80.0
# 2     68.0
# 3     60.0
# 4     84.0
# 5     85.0
# 6     75.0
# 7      NaN
# 8     51.0
# 9     50.0
# 10    70.0
# 11    85.0
# 12     NaN
# 13    91.0
# 14     NaN
# 15    51.0
# 16     NaN
# 17    72.0
# 18    66.0
# 19    70.0
# Name: LotFrontage, dtype: float64

# %%
#Subset 'LotFrontage' column and fill NaNs with the mean value of the column
#Update train dataset
NaN = train['LotFrontage']
NaN = train['LotFrontage'].fillna(float(0), inplace=True)
train.update(NaN)

# %%
train['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
#Check null values.
train['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
#Subset 'LotFrontage' column and fill NaNs with the mean value of the column
#Update train dataset
NaN2 = train['MasVnrArea']
NaN2 = train['MasVnrArea'].fillna(0, inplace=True)
train.update(NaN2)

# %%
#Some NaNs indicate that the house does not have that feature. 
#Replace the following columns with 'None':
#PoolQC, MiscFeature, Alley, Fence, FireplaceQu, GarageYrBlt, GarageCond, GarageType, GarageFinish, 
#GarageQual, BsmtFinType, BsmtExposure, BsmtQual, BsmtCond, BsmtFinType1, MasVnrArea, MasVnrType.
missing_cat = train[['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu','GarageYrBlt', 
                'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual','BsmtFinType2', 
                'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 
                'Electrical', 'MasVnrType']]
missing_cat = missing_cat.fillna('None')
missing_cat.head()
# Out:
#   PoolQC MiscFeature Alley Fence FireplaceQu GarageYrBlt GarageCond  \
# 0   None        None  None  None        None      2003.0         TA
# 1   None        None  None  None          TA      1976.0         TA
# 2   None        None  None  None          TA      2001.0         TA
# 3   None        None  None  None          Gd      1998.0         TA
# 4   None        None  None  None          TA      2000.0         TA
#
#   GarageType GarageFinish GarageQual BsmtFinType2 BsmtExposure BsmtQual  \
# 0     Attchd          RFn         TA          Unf           No       Gd
# 1     Attchd          RFn         TA          Unf           Gd       Gd
# 2     Attchd          RFn         TA          Unf           Mn       Gd
# 3     Detchd          Unf         TA          Unf           No       TA
# 4     Attchd          RFn         TA          Unf           Av       Gd
#
#   BsmtCond BsmtFinType1 Electrical MasVnrType
# 0       TA          GLQ      SBrkr    BrkFace
# ...

# %%
#Update train data set with updated categorical variables.
train.update(missing_cat)
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Check null values in entire train data set
train.isnull().sum().head(25)
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# Exterior2nd     0
# dtype: int64

# %%
train.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  None      Reg
# 1    2          20       RL         80.0     9600   Pave  None      Reg
# 2    3          60       RL         68.0    11250   Pave  None      IR1
# 3    4          70       RL         60.0     9550   Pave  None      IR1
# 4    5          60       RL         84.0    14260   Pave  None      IR1
# 5    6          50       RL         85.0    14115   Pave  None      IR1
# 6    7          20       RL         75.0    10084   Pave  None      Reg
# 7    8          60       RL          0.0    10382   Pave  None      IR1
# 8    9          50       RM         51.0     6120   Pave  None      Reg
# 9   10         190       RL         50.0     7420   Pave  None      Reg
# 10  11          20       RL         70.0    11200   Pave  None      Reg
# 11  12          60       RL         85.0    11924   Pave  None      IR1
# ...

# %%
#View histograms to see if there are any outliers
train.hist(figsize=(15,15))
plt.subplots_adjust(hspace=0.5)
plt.savefig('../images/histogram.png')
#LotArea max is 200,000
#TotalBsmtSF max is 5000

# %%
#Find LotArea max
train['LotArea'].max()
# Out:
# 215245

# %%
#Explore row with max Lot Area
lotarea_max = pd.DataFrame(train.loc[train['LotArea'].idxmax()])
lotarea_max.T
#Outlier
# Out:
#       Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 313  314         20       RL       150.0  215245   Pave  None      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 313         Low    AllPub    Inside       Sev       Timber       Norm
#
#     Condition2 BldgType HouseStyle OverallQual OverallCond YearBuilt  \
# 313       Norm     1Fam     1Story           7           5      1965
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 313         1965       Hip  CompShg     BrkFace     BrkFace       None
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 313        0.0        TA        TA     CBlock       Gd       TA           Gd
#
#     BsmtFinType1 BsmtFinSF1 BsmtFinType2 BsmtFinSF2 BsmtUnfSF TotalBsmtSF  \
# 313          ALQ       1236          Rec        820        80        2136
#
#     Heating HeatingQC CentralAir Electrical 1stFlrSF 2ndFlrSF LowQualFinSF  \
# ...

# %%
#Compare number to median
train['LotArea'].median()
# Out:
# 9478.5

# %%
#Total basement square feet max
train['TotalBsmtSF'].max()
# Out:
# 6110

# %%
#Explore TotalBsmtSF
totalbsmt_max = pd.DataFrame(train.loc[train['TotalBsmtSF'].idxmax()])
totalbsmt_max.T
# Out:
#         Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 1298  1299         60       RL       313.0   63887   Pave  None      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle OverallQual OverallCond YearBuilt  \
# 1298       Norm     1Fam     2Story          10           5      2008
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1298         2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 1298      796.0        Ex        TA      PConc       Ex       TA           Gd
#
#      BsmtFinType1 BsmtFinSF1 BsmtFinType2 BsmtFinSF2 BsmtUnfSF TotalBsmtSF  \
# 1298          GLQ       5644          Unf          0       466        6110
#
# ...

# %%
#Compare to median
train['TotalBsmtSF'].median()
# Out:
# 991.5

# %%
#The LotArea seems like the data were mistyped. Drop row.
#The TotalBsmtSF is accurate, even though value seemed high at first.

# %%
#Drop row and update data frame
train = train.drop([1298])

# %%
#print shape
print(train.shape)
# Out:
# (1459, 81)

# %%
#Reset the index and delete the new index row
train = train.reset_index()
del train['index']

# %%
#Print shape of data frame
print(train.shape)
# Out:
# (1459, 81)

# %%
#Find any duplicated entries
test_ids = test['Id']
test[ids.isin(ids.duplicated())].sort_values("Id")
# Out:
# /var/folders/p7/6x85vdds69qd2d2g4mg39v640000gp/T/ipykernel_42682/1154454326.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test[ids.isin(ids.duplicated())].sort_values("Id")
# Empty DataFrame
# ...

# %%
#Observe data
test.isna().sum().sort_values(ascending=False).head(34)
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# FireplaceQu      730
# LotFrontage      227
# GarageYrBlt       78
# GarageQual        78
# GarageFinish      78
# GarageCond        78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# KitchenQual        1
# TotalBsmtSF        1
# Exterior2nd        1
# GarageCars         1
# Exterior1st        1
# GarageArea         1
# SaleType           1
# MiscVal            0
# dtype: int64

# %%
#Explore missing values and figure out what to replace NaN's with.
missing_test = test[['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
                      'GarageYrBlt', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual',
                      'BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 
                      'MasVnrArea', 'MasVnrType', 'Electrical', 'MSZoning', 'BsmtHalfBath', 'BsmtFullBath',
                      'BsmtFinSF1','BsmtFinSF2', 'Utilities', 'Functional', 'Exterior1st', 'SaleType', 'Exterior2nd',
                      'KitchenQual']]
missing_test = missing_test.fillna('None')
missing_test.head(30)
# Out:
#    PoolQC MiscFeature Alley  Fence FireplaceQu GarageYrBlt GarageCond  \
# 0    None        None  None  MnPrv        None      1961.0         TA
# 1    None        Gar2  None   None        None      1958.0         TA
# 2    None        None  None  MnPrv          TA      1997.0         TA
# 3    None        None  None   None          Gd      1998.0         TA
# 4    None        None  None   None        None      1992.0         TA
# 5    None        None  None   None          TA      1993.0         TA
# 6    None        Shed  None  GdPrv        None      1992.0         TA
# 7    None        None  None   None          Gd      1998.0         TA
# 8    None        None  None   None          Po      1990.0         TA
# 9    None        None  None  MnPrv        None      1970.0         TA
# 10   None        None  None   None          Fa      1999.0         TA
# 11   None        None  None   None        None      1971.0         TA
# ...

# %%
#Update train data set with updated categorical variables.
test.update(missing_test)
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  None      Reg
# 1  1462          20       RL         81.0    14267   Pave  None      IR1
# 2  1463          60       RL         74.0    13830   Pave  None      IR1
# 3  1464          60       RL         78.0     9978   Pave  None      IR1
# 4  1465         120       RL         43.0     5005   Pave  None      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
np.sum(test.isnull()).sort_values(ascending=False).head(10)
# Out:
# LotFrontage     227
# GarageCars        1
# GarageArea        1
# TotalBsmtSF       1
# BsmtUnfSF         1
# BedroomAbvGr      0
# FireplaceQu       0
# Fireplaces        0
# Functional        0
# TotRmsAbvGrd      0
# dtype: int64

# %%
#Subset 'LotFrontage' column and fill NaNs with the mean value of the column
#Update train dataset
test_lot_NaN = test['LotFrontage']
test_lot_NaN = test['LotFrontage'].fillna(float(0), inplace=True)
test.update(test_lot_NaN)

# %%
#fill rest of the values with 0
test = test.fillna(0)

# %%
#View sum of null values
np.sum(test.isnull()).sort_values(ascending=False).head(5)
# Out:
# Id             0
# MSSubClass     0
# GarageType     0
# FireplaceQu    0
# Fireplaces     0
# dtype: int64

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave  None      Reg
# 1     1462          20       RL         81.0    14267   Pave  None      IR1
# 2     1463          60       RL         74.0    13830   Pave  None      IR1
# 3     1464          60       RL         78.0     9978   Pave  None      IR1
# 4     1465         120       RL         43.0     5005   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave  None      Reg
# 1455  2916         160       RM         21.0     1894   Pave  None      Reg
# 1456  2917          20       RL        160.0    20000   Pave  None      Reg
# 1457  2918          85       RL         62.0    10441   Pave  None      Reg
# 1458  2919          60       RL         74.0     9627   Pave  None      Reg
#
# ...

# %%
test['LotFrontage']
# Out:
# 0        80.0
# 1        81.0
# 2        74.0
# 3        78.0
# 4        43.0
#         ...
# 1454     21.0
# 1455     21.0
# 1456    160.0
# 1457     62.0
# 1458     74.0
# Name: LotFrontage, Length: 1459, dtype: float64

# %%
#save clean test and train data set 
test.to_csv('../data/clean_test.csv', index=False)
train.to_csv('../data/clean_train.csv', index=False)
