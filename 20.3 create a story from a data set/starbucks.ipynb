# %%
#Create a story from a data set 
#Created on March 2, 2023
#rubric link: https://docs.google.com/document/d/1dp3rOhTjHwjN5lOkXUYc8Qtr6mXE89PuuCV1afSavgk/edit

# %%
#Notebook should contain the following: 
#The questions you asked
#The trends you investigated
#The resulting visualizations and conclusions

# %%
#import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
allresults = []

# %%
#import data set
df = pd.read_csv("data/starbucks_drinkMenu_expanded.csv")

# %%
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             242 non-null    object
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
#Replace cells with '-' with NaN
df = df.mask(df == '-')

# %%
np.sum(df.isna())
# Out:
# Beverage_category            0
# Beverage                     0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                1
# dtype: int64

# %%
df.shape
# Out:
# (242, 18)

# %%
#drop nans
df = df.dropna()

# %%
#view data frame
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
#Intro
#The purpose of this exercise is investigate 
#and caffeine (mg) content of various starbucks drinks
#while considering calories and sugar content.

# %%
plt.figure(figsize=(7,4))
plot = sns.barplot(y=df['Calories'], x=df['Beverage_category']).set(xlabel='Category', ylabel='Average Calories', title='Average Calories per Beverage Category')
plt.xticks(rotation=90)
plt.show()

# %%
df['Caffeine (mg)'].unique()
# Out:
# array(['175', '260', '330', '410', '75', '150', '85', '95', '180', '225',
#        '300', '10', '20', '25', '30', '0', 'Varies', '50', '70', '120',
#        '55', '80', '110', 'varies', '165', '235', '90', '125', '170',
#        '15', '130', '140', '100', '145', '65', '105'], dtype=object)

# %%
df['Caffeine (mg)'].shape
# Out:
# (241,)

# %%
varies = df[ (df['Caffeine (mg)'] == 'Varies') | (df['Caffeine (mg)'] == 'varies') ].index
df.drop(varies, inplace=True)
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df['Caffeine (mg)'] = df['Caffeine (mg)'].astype(int)

# %%
#Model to predict how much calories and caffeine a drink may have

# %%
plt.figure(figsize=(7,4))
plot = sns.barplot(y=df['Caffeine (mg)'], x=df['Beverage_category']).set(xlabel='Category', ylabel='Average Caffeine (mg)', title='Average Caffeine per Beverage Category')
plt.xticks(rotation=90)
plt.show()

# %%
df = df.rename(columns={' Sugars (g)': 'Sugars (g)'})

# %%
df['Sugars (g)'].unique()
# Out:
# array([ 0,  9,  4, 14,  6, 18, 17,  8, 23, 22, 11, 13, 27, 26, 20, 34, 44,
#        43, 33, 35, 45,  7,  3, 10,  5, 16, 21, 15, 24, 32, 41, 40, 31, 29,
#        25, 39, 58, 51, 74, 64, 55, 54, 49, 65, 83, 28, 42, 37, 53, 46, 56,
#        71, 19, 30, 38, 36, 50, 47, 69, 66, 76, 73, 59, 77, 62, 60, 84, 80,
#        52, 68])

# %%
plt.figure(figsize=(7,4))
plot = sns.barplot(y=df['Sugars (g)'], x=df['Beverage_category']).set(xlabel='Category', ylabel='Average Sugar (g)', title='Average Sugar per Beverage Category')
plt.xticks(rotation=90)
plt.show()

# %%
#Audience: non-technical, nutrition

#Starbucks is one of the leading companies in the food industry today.  With 35,000 stores globally, Starbucks
#remains a popular food and beverage provider for people of all ages. Whether you are heading to starbucks for 
#a hot coffee to wake you up and keep you warm in the early morning, or an iced tea to cool you down on 
#a summer day, Starbucks has a variety of options to ensure you can get your perfect drink. 
#At Starbucks, there are a variety of drinks such as coffees, teas, smoothies, blended coffees, etc. 
#You can even customize your drink with one, or more, of their 16 different syrups, whipped cream, toppings
#and sauces.  However, not all starbucks drinks are not created with the same amount of caffiene and sugar content.
#The graphs above show that some drinks have no caffeine at all while others have 300 mg of caffiene. 
#They also show that some starbucks drinks have 0 grams of sugar, while others have up to 60 mg of sugar. 

#The FDA states that the average adult can drink up to 400mg of caffiene per day without having adverse effects.
#The AHA recommends that adult women and men intake no more than a daily amount of 24 g and 26 g of sugar, 
#respectively. That being said, it is important to understand how much caffiene and sugar your favorite starbucks
#drinks contain. We can use this data set to predict how much caffeiene and sugar your customized drinks
#contain to ensure you are staying within the recommended daily limit.
